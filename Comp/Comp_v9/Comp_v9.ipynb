# %%
receipt_data_file = input("명세서 폴더 경로를 입력해주세요. (바로 Enter를 누르면 디폴트 경로가 설정됩니다)")

if receipt_data_file == '':
    receipt_data_file = 'C:/Users/hyb95_000/Desktop/체크카드 명세서/shinhancard_*.html'
    
else:
    receipt_data_file = receipt_data_file + "/shinhancard_*.html"
# Out:
# 명세서 폴더 경로를 입력해주세요. (바로 Enter를 누르면 디폴트 경로가 설정됩니다)

# %%
import pandas as pd
from bs4 import BeautifulSoup
import glob
from selenium import webdriver
import requests 
import os
import time
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# 체크카드 명세서 자동 불러오기
receipt_data_file = glob.glob('C:/Users/hyb95_000/Desktop/체크카드 명세서/shinhancard_*.html') # 지정 폴더안에 있는 모든 파일을 불러내기 위함

# excel_writer로 보낼 data 모음
total_df = []             # 일별 DataFrame 모음
total_df_region = []      # 지역별 DataFrame 모음
List_Sum_Month_tdf = []   # 월별 합계 DataFrame 모음
sheet_nm = []             # Excel Sheet Name 모음
visit_graph = []          # 월별 방문횟수 그래프 모음

# 위의 'total_df'와 'sheet_nm'에 데이터를 삽입하기 위한 for 구문
for url in receipt_data_file :
    driver = webdriver.Chrome('c:/chromedriver.exe')
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    title_tag = soup.select('head > title')
    title = title_tag[0].text
    
    # 암호된 문서일 경우 if 구문으로 들어감
    if title == '' :
        pw = '950730'
        driver.find_element_by_id('password').send_keys(pw)
        driver.find_element_by_xpath('//*[@id="aform"]/span/input').click()
        time.sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html,'html.parser')
        
    # 암호된 문서가 아닐 경우 아래코드로 바로 들어감
    # 명세서 데이터에서 체크 소계 제거 코드
    tables = soup.select('div#email02 > table.tblList.cardUseList > tbody > tr')
    tables_middleSum = soup.select('div#email02 > table.tblList.cardUseList > tbody > tr.middleSum')
    
    for n in range(len(tables_middleSum)) :
        tables.remove(tables_middleSum[n])
    
    # tables 데이터 string으로 변환하여 분리                      
    seperate_tables = []                        # seperate_tables 초기화
    for n in range(len(tables)) :
        table = str(tables[n].text).split('\n')
        seperate_tables = seperate_tables + table
        
    # seperate_tables에서 '사용날짜' , '사용금액', '사용처' 추출   
    date_list =  [seperate_tables[n] for n in range(1,len(seperate_tables), 12)]
    price_list = [int(seperate_tables[n].replace(',','')) for n in range(4,len(seperate_tables), 12)] 
    store_list = [seperate_tables[n].replace(" ", "") for n in range(3,len(seperate_tables), 12)]

    # seperate_tables에서 추출된 '사용처' 데이터 --> 카카오 지도 API --> '사용처'에 대한 주소 추출
    location_list = []
    def create_url(search_text):
        headers = {'Authorization': 'KakaoAK 3e8ea332f0cdef6293383ac7bf81a6fc'}
        base = "https://dapi.kakao.com/v2/local/search/keyword.json"
        param_query = "?query=" +search_text
        respond = requests.get(base + param_query,headers=headers)
        return respond.json()

    for n in range(len(store_list)) :
        store_name = store_list[n]
        result = create_url(store_name)
        tmp1 = result['documents']
        try :
            tmp2 = tmp1[0]['address_name']
            location_list.append(tmp2)
        except :
            tmp2 = np.nan
            location_list.append(tmp2)
            
    # 추출한 데이터로 DataFrame 변환
    table_data = {'사용날짜':date_list, '사용처':store_list, '사용처주소':location_list,  '사용금액':price_list }
    
    df = pd.DataFrame(table_data, index = range(1,len(date_list)+1,1), columns=['사용날짜', '사용처', '사용처주소', '사용금액'])
    df_sum = pd.DataFrame(df.sum(), columns=['합계'])
    df_total = df.append(df_sum.T)
    df_total.loc['합계', '사용날짜'] = '전체'
    df_total.loc['합계', '사용처'] = '전체'
    df_total.loc['합계', '사용처주소'] = '전체'
    total_df.append(df_total)
    List_Sum_Month_tdf.append(df_sum.T['사용금액'])    # 선그래프를 그리기 위한 합계를 List_Sum_Month_tdf=[]로 보낸다.
        
   # 월별기준 지역별 사용데이터 추출  
    df_dis_nan = df.dropna()

    df_address_list = list(df_dis_nan['사용처주소'])
    df_region_list = [ ' '.join(address.split()[:2]) for address in df_address_list]

    df_price_list = list(df_dis_nan['사용금액'])

    table_data_1 = {'사용지역':df_region_list, '사용금액':df_price_list}
    col_list = ['사용지역', '사용금액']
    df_Dup = pd.DataFrame(table_data_1 , columns = col_list ) # 중복값이 있는 df
    df_NoDup = df_Dup.drop_duplicates(subset = '사용지역')  # 중복값이 없는 df

    index_name_1 = df_Dup['사용지역']  # 중복값이 있는 사용지역 series
    df_Dup_name = df_Dup.rename(index_name_1)
    df_Dup_name = df_Dup_name.drop(['사용지역'], axis = 1)  # 중복값이 있고 사용지역이 index인 df

    index_name_2 = df_NoDup['사용지역']  # 중복값이 없는 사용지역 series
    df_NoDup_name = df_NoDup.rename(index_name_2)
    df_NoDup_name = df_NoDup_name.drop(['사용지역'], axis = 1)  # 중복값이 없고 사용지역이 index인 df

    for nm in list(index_name_2) :
        price_data = df_Dup_name.loc[nm]['사용금액']
        price_sum = price_data.sum()
        df_NoDup_name.loc[nm]['사용금액'] = price_sum

    name_region = df_Dup['사용지역']
    visit_counter = dict(name_region.value_counts())
    counter_list = []
    for k in index_name_2 :
        counter_list.append(visit_counter[k])
    
    df_NoDup_name.insert(0, '방문횟수', counter_list)
    total_df_region.append(df_NoDup_name)
    
    # 엑셀 시트네임 데이터 추출
    tables_date = soup.select('body > div.wrap.check > div.content > div.receiveDate > span.date')
    nm = str(tables_date[0].text)
    sheet_nm.append(nm)
    
    # 팝업창 닫기
    driver.close()

# 엑셀 및 이미지 저장 폴더 만들기
folder = 'C:/Users/hyb95_000/Desktop/체크카드 명세서'
folder_1 = 'C:/Users/hyb95_000/Desktop/체크카드 명세서/image'

if not os.path.exists(folder) :
    os.makedirs(folder)

if not os.path.exists(folder_1) :
    os.makedirs(folder_1)
    
# 월별 사용금액 데이터 시각화(엑셀 첫번째 시트에 들어감)
     
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False      
    
plt.subplots(1,1, figsize=[10,7])
plt.plot(sheet_nm, List_Sum_Month_tdf, 'o-r')

plt.xticks(rotation=360)

plt.tick_params(axis='x', labelsize=12, color='r')
plt.tick_params(axis='y', labelsize=12, color='r')

plt.xlabel('날짜', fontsize = 15)
plt.ylabel('사용 금액', fontsize = 15)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)  # 지수 표현 방지
plt.title('월별 카드 사용 금액', fontsize = 15)

plt.grid(True)

graph_file = "C:/Users/hyb95_000/Desktop/체크카드 명세서/image/mcua.png"

plt.savefig(graph_file, dpi = 200)
    
# 월별 지역 방문 횟수 데이터 시각화

for n in range(len(total_df_region)) :
    a0 = total_df_region[n][["방문횟수"]].plot.bar(grid = True, rot=45, figsize=[10,8], fontsize = 15)
    a0.set_xlabel("지역",fontsize = 15)
    a0.set_ylabel("방문 횟수",fontsize = 15)
    a0.set_title(f"{sheet_nm[n]} 지역별 방문횟수", fontsize = 20)
    plt.tick_params(axis='x', labelsize=10)
    plt.tick_params(axis='y', labelsize=10)
    plt.xticks(rotation=45)
    visit_file = f"C:/Users/hyb95_000/Desktop/체크카드 명세서/image/{sheet_nm[n]} 지역별 사용 금액.png" 
    plt.savefig(visit_file,dpi = 200)
    visit_graph.append(visit_file)

# total_df, total_df_region, sheet_nm 데이터를 활용하여 Excel로 저장
    
excel_writer = pd.ExcelWriter('C:/Users/hyb95_000/Desktop/체크카드 명세서/CardUseList.xlsx', engine='xlsxwriter')

df_empty = pd.DataFrame()
df_empty.to_excel(excel_writer, index = True, sheet_name = 'Sheet1')
worksheet = excel_writer.sheets['Sheet1']
worksheet.insert_image('D2', graph_file)

ToExcel_data =[]

for n in range(len(total_df)) :
    ToAppend_total_df = total_df[n].to_excel(excel_writer, index = True, sheet_name = sheet_nm[n]+' 데이터')
    ToExcel_data.append(ToAppend_total_df)
    
    ToAppend_total_region_df = total_df_region[n].to_excel(excel_writer, index = True, sheet_name = sheet_nm[n]+' 데이터', startcol=6)
    worksheet_1 = excel_writer.sheets[sheet_nm[n]+' 데이터']
    send_worksheet_1 = worksheet_1.insert_image('K1', visit_graph[n])
    ToExcel_data.append(ToAppend_total_region_df)
    ToExcel_data.append(send_worksheet_1)

excel_writer.save()

# %%
df_address = [] # 위치정보 없는 데이터 삭제한 DF 넣을 리스트
df_address_only = [] # 중복 사용지점 없는 DF 넣을 리스트
data_in_name = []
data_in_only_name = []
count_list = []

# 위치정보 없는 데이터 삭제한 DF 만들기
df_address = [df.dropna() for df in total_df]

# 중복 사용지점 없는 DF 만들기
df_address_only = [df.drop_duplicates(subset = '사용처') for df in df_address]

for i in range(len(df_address)):
    
    name_index =  df_address[i]['사용처']
    data_in_name.append(df_address[i].rename(name_index))
    data_in_name[i] = data_in_name[i].drop(['사용처'], axis = 1)

    name_index =  df_address_only[i]['사용처']
    data_in_only_name.append(df_address_only[i].rename(name_index))
    data_in_only_name[i] = data_in_only_name[i].drop(['사용처'], axis = 1)
    
    for name in list(name_index):
        tmp_data = data_in_name[i].loc[name]['사용금액']
        
        try:
            price_sum = sum(data_in_name[i].loc[name]['사용금액'])

        except:
            price_sum = data_in_name[i].loc[name]['사용금액']
            
        data_in_only_name[i].loc[name]['사용금액'] = price_sum
            
            
#     for name in list(name_index):
#         tmp_data = data_in_name[i].loc[name]['사용금액']

#         if type(tmp_data) != str:
#             price = [price.replace(',','') for price in tmp_data]
#             price = list(map(int, price))
#             price_sum = sum(price)
#             data_in_only_name.loc[name]['사용금액'] = price_sum

#         else:
#             data_in_only_name.loc[name]['사용금액'] = int(tmp_data.replace(',',''))


    name_series = df_address[i]['사용처']

    visit_count = dict(name_series.value_counts())

    count_list_tmp = []

    for k in name_index:
        count_list_tmp.append(visit_count[k])

        
    count_list.append(count_list_tmp)
    
    # 사용횟수 열 추가하기

    data_in_only_name[i].insert(3, '방문횟수', count_list[i])

import requests

coordinates_x = []
coordinates_y = []

def getLatLng(address):
    result = ""
 
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    rest_api_key = '289858dc68417f30677b064987b71bab'
    header = {'Authorization': 'KakaoAK ' + rest_api_key}
 
    r = requests.get(url, headers=header)
 
    if r.status_code == 200:
        try:
            result_address = r.json()["documents"][0]["address"]
            result = result_address["y"], result_address["x"]
        except:
            result = False
    else:
        result = "ERROR[" + str(r.status_code) + "]"
    
    return result

for i in range(len(data_in_only_name)):

    date = list(data_in_only_name[i]['사용날짜'][:-1])
    store_name = list(data_in_only_name[i].index[:-1])
    address = list(data_in_only_name[i]['사용처주소'][:-1])
    price = list(data_in_only_name[i]['사용금액'][:-1])
    count = list(data_in_only_name[i]['방문횟수'][:-1])

    #     count = count_list[i][:-1]


    coordinates_x = []
    coordinates_y = []
    
    for j in address:
        
        coor = getLatLng(j)
        

        if coor != False:
            coordinates_x.append(coor[0])
            coordinates_y.append(coor[1])
        else:
            coordinates_x.append(False)
            coordinates_y.append(False)

    html = '<div id="map" style="width:100%;height:100%;"></div>'
    html = html + '<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>\n'
    html = html + '<script>\n'
    html = html + "var mapContainer = document.getElementById('map'), \n"
    html = html + '    mapOption = { \n'

    html = html + '        center: new kakao.maps.LatLng(37.566826, 126.9786567), \n'
    html = html + '        level: 7 \n'
    html = html + '    };'

    html = html + """
    var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다

    // 마커를 표시할 위치와 title 객체 배열입니다 

    var positions = []
    """
    for k in range(len(store_name)):
        if coordinates_x[k] == False:
            continue
        html = html + "positions.push({ title: " + f"'{store_name[k]}', price: '{price[k]}', count: '{count[k]}'," + f" latlng: new kakao.maps.LatLng({coordinates_x[k]}, {coordinates_y[k]})" + "})\n"

    html = html + """
    // 마커 이미지의 이미지 주소입니다
    var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png"; 

    for (var i = 0; i < positions.length; i ++) {

        // 마커 이미지의 이미지 크기 입니다
        //var imageSize = new kakao.maps.Size(24, 35); 

        // 마커 이미지를 생성합니다    
        //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize); 

        // 마커를 생성합니다
        var marker = new kakao.maps.Marker({
            map: map, // 마커를 표시할 지도
            position: positions[i].latlng, // 마커를 표시할 위치
        //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
        //    image : markerImage // 마커 이미지 
        });

        var infowindow = new kakao.maps.InfoWindow({
            //position : positions[i].latlng, 
            content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
        });
        
        
        kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
        kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
        
        //marker.setMap(map);


        //infowindow.open(map, marker); 
        
        

    }
    
    function makeOverListener(map, marker, infowindow) {
        return function() {
            infowindow.open(map, marker);
        };
    }

    // 인포윈도우를 닫는 클로저를 만드는 함수입니다 
    function makeOutListener(infowindow) {
        return function() {
            infowindow.close();
        };
    }
    
    </script>"""

    map_file = open('map_' + sheet_nm[i] + '.html', 'w')
    map_file.write(html)
    map_file.close()

    print(html)
# Out:
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '자판기', price: '1000', count: '1', latlng: new kakao.maps.LatLng(37.5383303723553, 126.987097452984)})
# positions.push({ title: '다이소(공릉점)', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.6264557243819, 127.074491271089)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '22200', count: '5', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '이마트24노원공릉점', price: '4800', count: '2', latlng: new kakao.maps.LatLng(37.6249345631284, 127.077743114464)})
# positions.push({ title: '씨유서울과학기술대2관점', price: '2340', count: '1', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '전설의짬뽕공릉점', price: '8500', count: '1', latlng: new kakao.maps.LatLng(37.6272155316648, 127.077284772024)})
# positions.push({ title: 'CU공릉플러스점', price: '1400', count: '1', latlng: new kakao.maps.LatLng(37.626849440018, 127.076487117736)})
# positions.push({ title: '주식회사진선우유통', price: '6930', count: '1', latlng: new kakao.maps.LatLng(37.6264443920501, 127.078896187208)})
# positions.push({ title: '씨유서울과학기술대1관점', price: '5040', count: '2', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '성민양꼬치', price: '66000', count: '1', latlng: new kakao.maps.LatLng(37.4770960370923, 126.984382794844)})
# positions.push({ title: '모던PC방', price: '6000', count: '1', latlng: new kakao.maps.LatLng(36.026033541923, 129.339411011168)})
# positions.push({ title: '배스킨라빈스공릉점', price: '5600', count: '1', latlng: new kakao.maps.LatLng(37.6274647024526, 127.078576223252)})
# positions.push({ title: '세븐PC방', price: '3000', count: '1', latlng: new kakao.maps.LatLng(37.5668574213701, 127.061836032168)})
# positions.push({ title: '써브웨이고려대점', price: '5800', count: '1', latlng: new kakao.maps.LatLng(37.5861329467313, 127.02902638623)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '자판기', price: '1000', count: '1', latlng: new kakao.maps.LatLng(37.5383303723553, 126.987097452984)})
# positions.push({ title: '성민양꼬치', price: '62000', count: '1', latlng: new kakao.maps.LatLng(37.4770960370923, 126.984382794844)})
# positions.push({ title: '네이버주식회사', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.3942796422602, 127.112131255488)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '11200', count: '4', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '라렌', price: '14000', count: '1', latlng: new kakao.maps.LatLng(37.4806047633012, 127.12366621502)})
# positions.push({ title: 'CU공릉플러스점', price: '2300', count: '2', latlng: new kakao.maps.LatLng(37.626849440018, 127.076487117736)})
# positions.push({ title: '리코스타코인노래연습장', price: '6000', count: '2', latlng: new kakao.maps.LatLng(37.5421539451273, 127.068550278641)})
# positions.push({ title: '뚜레쥬르공릉점', price: '29850', count: '1', latlng: new kakao.maps.LatLng(37.6279956104976, 127.07686359966)})
# positions.push({ title: '쥬씨', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.5422746883706, 127.071423015129)})
# positions.push({ title: '씨유서울과학기술대2관점', price: '4140', count: '2', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '호치킨', price: '23300', count: '1', latlng: new kakao.maps.LatLng(37.6517968884864, 127.046623232877)})
# positions.push({ title: '서양국수집', price: '5900', count: '1', latlng: new kakao.maps.LatLng(37.6291220286431, 127.076717262671)})
# positions.push({ title: '무봉리토종순대국', price: '17000', count: '1', latlng: new kakao.maps.LatLng(37.8151886421439, 127.135395671079)})
# positions.push({ title: '잔월', price: '25000', count: '1', latlng: new kakao.maps.LatLng(37.6263534683487, 127.075192150346)})
# positions.push({ title: '기린', price: '5900', count: '1', latlng: new kakao.maps.LatLng(36.7318599371288, 127.451090031658)})
# positions.push({ title: '맥도날드', price: '4900', count: '1', latlng: new kakao.maps.LatLng(37.4987083234515, 127.028660034939)})
# positions.push({ title: '주)스타벅스커피코리아', price: '4100', count: '1', latlng: new kakao.maps.LatLng(37.5601755439283, 126.982921061075)})
# positions.push({ title: '쪼매매운떡볶이', price: '16000', count: '1', latlng: new kakao.maps.LatLng(37.6282962949983, 127.077787284753)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '이마트24노원공릉점', price: '32200', count: '8', latlng: new kakao.maps.LatLng(37.6249345631284, 127.077743114464)})
# positions.push({ title: '맥도날드', price: '16800', count: '3', latlng: new kakao.maps.LatLng(37.4987083234515, 127.028660034939)})
# positions.push({ title: '다이소(공릉점)', price: '9020', count: '1', latlng: new kakao.maps.LatLng(37.6264557243819, 127.074491271089)})
# positions.push({ title: '자판기', price: '1200', count: '1', latlng: new kakao.maps.LatLng(37.5383303723553, 126.987097452984)})
# positions.push({ title: '고고치킨', price: '8500', count: '1', latlng: new kakao.maps.LatLng(37.1643893074094, 127.063586129086)})
# positions.push({ title: '리코스타코인노래연습장', price: '3000', count: '1', latlng: new kakao.maps.LatLng(37.5421539451273, 127.068550278641)})
# positions.push({ title: '화로상회공릉점', price: '13700', count: '1', latlng: new kakao.maps.LatLng(37.6268788964919, 127.079494773049)})
# positions.push({ title: '탐앤탐스공릉역점', price: '8000', count: '2', latlng: new kakao.maps.LatLng(37.6265124000315, 127.074628171091)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '29500', count: '9', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '씨유서울과학기술대2관점', price: '15660', count: '6', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '주)우아한형제들', price: '78200', count: '3', latlng: new kakao.maps.LatLng(37.5169302452841, 127.112781230361)})
# positions.push({ title: '밥은', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.7870312180427, 128.907981003376)})
# positions.push({ title: '쿠팡', price: '32220', count: '1', latlng: new kakao.maps.LatLng(37.5157751181814, 127.099062233457)})
# positions.push({ title: '씨유서울과학기술대1관점', price: '3060', count: '2', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '찬이네곱창', price: '19000', count: '1', latlng: new kakao.maps.LatLng(37.6287947641555, 127.076757708689)})
# positions.push({ title: '이동재스시', price: '34000', count: '1', latlng: new kakao.maps.LatLng(37.5559901334178, 127.07770617789)})
# positions.push({ title: 'GS25공릉타운점', price: '5400', count: '3', latlng: new kakao.maps.LatLng(37.6259433093151, 127.078421693524)})
# positions.push({ title: 'GS25S공릉역점', price: '14000', count: '1', latlng: new kakao.maps.LatLng(37.6257624214235, 127.072748334999)})
# positions.push({ title: '더블유(W)', price: '3000', count: '1', latlng: new kakao.maps.LatLng(38.1962307589859, 128.578396394655)})
# positions.push({ title: '느린마을양조장건대점', price: '57000', count: '1', latlng: new kakao.maps.LatLng(37.5407394005722, 127.069586126579)})
# positions.push({ title: '라렌', price: '17000', count: '1', latlng: new kakao.maps.LatLng(37.4806047633012, 127.12366621502)})
# positions.push({ title: '네이버파이낸셜(주)', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.3595166368758, 127.105210637192)})
# positions.push({ title: '씨제이올리브네트웍스(주)공릉역점', price: '38800', count: '1', latlng: new kakao.maps.LatLng(37.615547516276, 127.063968435828)})
# positions.push({ title: '명랑시대쌀핫도그', price: '1000', count: '1', latlng: new kakao.maps.LatLng(37.5700529839714, 126.98998140988)})
# positions.push({ title: '써브웨이', price: '7000', count: '1', latlng: new kakao.maps.LatLng(35.8842235941545, 128.656850477801)})
# positions.push({ title: '씨유공릉스타점', price: '9420', count: '1', latlng: new kakao.maps.LatLng(37.6267621309689, 127.075231190965)})
# positions.push({ title: '숲속왕돈까스', price: '6500', count: '1', latlng: new kakao.maps.LatLng(37.6289454851633, 127.076640614042)})
# positions.push({ title: '빽다방서울과기대점', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.6286765044367, 127.077111260585)})
# positions.push({ title: '새백조약국', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.6271812184395, 127.079165784234)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '자판기', price: '2200', count: '2', latlng: new kakao.maps.LatLng(37.5383303723553, 126.987097452984)})
# positions.push({ title: '빽다방서울과기대점', price: '17100', count: '4', latlng: new kakao.maps.LatLng(37.6286765044367, 127.077111260585)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '37550', count: '10', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '빽다방안암역점', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.5866684958712, 127.030109549294)})
# positions.push({ title: '씨유고대동문점', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.5836819054777, 127.029308474757)})
# positions.push({ title: '씨유성북안암', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.5807248570075, 127.025364834574)})
# positions.push({ title: '밥은', price: '21500', count: '3', latlng: new kakao.maps.LatLng(37.7870312180427, 128.907981003376)})
# positions.push({ title: '츠판러마', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.6244212585384, 127.076521558257)})
# positions.push({ title: 'GS25공릉타운점', price: '2300', count: '1', latlng: new kakao.maps.LatLng(37.6259433093151, 127.078421693524)})
# positions.push({ title: '이마트24노원공릉점', price: '8900', count: '2', latlng: new kakao.maps.LatLng(37.6249345631284, 127.077743114464)})
# positions.push({ title: 'GS25사당신동아점', price: '7400', count: '1', latlng: new kakao.maps.LatLng(37.4884554912542, 126.979568529184)})
# positions.push({ title: '네이버파이낸셜(주)', price: '10000', count: '3', latlng: new kakao.maps.LatLng(37.3595166368758, 127.105210637192)})
# positions.push({ title: '나라아트센터', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.6288901638869, 127.076363802951)})
# positions.push({ title: '다이소(공릉점)', price: '5000', count: '2', latlng: new kakao.maps.LatLng(37.6264557243819, 127.074491271089)})
# positions.push({ title: '라렌', price: '17000', count: '1', latlng: new kakao.maps.LatLng(37.4806047633012, 127.12366621502)})
# positions.push({ title: '주)스타벅스커피코리아', price: '4100', count: '1', latlng: new kakao.maps.LatLng(37.5601755439283, 126.982921061075)})
# positions.push({ title: '주)우아한형제들', price: '92900', count: '5', latlng: new kakao.maps.LatLng(37.5169302452841, 127.112781230361)})
# positions.push({ title: '씨유성균관대경영관점', price: '2880', count: '1', latlng: new kakao.maps.LatLng(37.5887469561476, 126.991927598859)})
# positions.push({ title: '맥도날드', price: '8200', count: '2', latlng: new kakao.maps.LatLng(37.4987083234515, 127.028660034939)})
# positions.push({ title: '(주)코리아세븐과기대점', price: '9000', count: '1', latlng: new kakao.maps.LatLng(37.6277728658225, 127.09048756502)})
# positions.push({ title: '숲속왕돈까스', price: '6500', count: '1', latlng: new kakao.maps.LatLng(37.6289454851633, 127.076640614042)})
# positions.push({ title: '취향저격', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.5956205449237, 127.060824072898)})
# positions.push({ title: '신의주찹쌀순대', price: '7000', count: '1', latlng: new kakao.maps.LatLng(37.6399362512699, 127.064257298855)})
# positions.push({ title: '알파문구공릉역점', price: '1200', count: '1', latlng: new kakao.maps.LatLng(37.6263919476469, 127.072297411214)})
# positions.push({ title: '주식회사진선우유통', price: '6930', count: '1', latlng: new kakao.maps.LatLng(37.6264443920501, 127.078896187208)})
# positions.push({ title: '호치킨', price: '23900', count: '1', latlng: new kakao.maps.LatLng(37.6517968884864, 127.046623232877)})
# positions.push({ title: '기린', price: '5900', count: '1', latlng: new kakao.maps.LatLng(36.7318599371288, 127.451090031658)})
# positions.push({ title: 'CU공릉플러스점', price: '9700', count: '1', latlng: new kakao.maps.LatLng(37.626849440018, 127.076487117736)})
# positions.push({ title: '7일간의양심', price: '106000', count: '1', latlng: new kakao.maps.LatLng(37.6262170742682, 127.073306458241)})
# positions.push({ title: '지지고서울과기대점', price: '88000', count: '2', latlng: new kakao.maps.LatLng(37.6293964159781, 127.076521447735)})
# positions.push({ title: '씨유서울과학기술대2관점', price: '720', count: '1', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '에이스문화사', price: '4600', count: '1', latlng: new kakao.maps.LatLng(37.6282962949983, 127.077787284753)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '주)우아한형제들', price: '118900', count: '6', latlng: new kakao.maps.LatLng(37.5169302452841, 127.112781230361)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '43100', count: '11', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '밥은', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.7870312180427, 128.907981003376)})
# positions.push({ title: '다이소(공릉점)', price: '3500', count: '2', latlng: new kakao.maps.LatLng(37.6264557243819, 127.074491271089)})
# positions.push({ title: '이마트24노원공릉점', price: '6800', count: '3', latlng: new kakao.maps.LatLng(37.6249345631284, 127.077743114464)})
# positions.push({ title: '슈퍼보드', price: '2800', count: '1', latlng: new kakao.maps.LatLng(37.2089395549549, 127.063782782632)})
# positions.push({ title: '피쉬앤그릴(신당점)', price: '149500', count: '1', latlng: new kakao.maps.LatLng(37.5640358877946, 127.015604662481)})
# positions.push({ title: '세븐PC방', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.5668574213701, 127.061836032168)})
# positions.push({ title: '주)스타벅스커피코리아', price: '4800', count: '1', latlng: new kakao.maps.LatLng(37.5601755439283, 126.982921061075)})
# positions.push({ title: 'GS25공릉타운점', price: '8400', count: '2', latlng: new kakao.maps.LatLng(37.6259433093151, 127.078421693524)})
# positions.push({ title: 'CU대성리점', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.6833043225725, 127.378619880203)})
# positions.push({ title: '넘버원부대찌개', price: '22000', count: '1', latlng: new kakao.maps.LatLng(37.6285645918387, 127.072728296047)})
# positions.push({ title: '사나이뚝배기과기대점', price: '22000', count: '2', latlng: new kakao.maps.LatLng(37.6293964159781, 127.076521447735)})
# positions.push({ title: '(주)신세계페이먼츠', price: '0', count: '2', latlng: new kakao.maps.LatLng(37.5604057613848, 126.979595754951)})
# positions.push({ title: '인터파크쇼핑', price: '24170', count: '1', latlng: new kakao.maps.LatLng(37.5079944172601, 127.056491346376)})
# positions.push({ title: '씨유서울과학기술대2관점', price: '5100', count: '3', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '에이스문화사', price: '26400', count: '3', latlng: new kakao.maps.LatLng(37.6282962949983, 127.077787284753)})
# positions.push({ title: '주식회사진선우유통', price: '12700', count: '2', latlng: new kakao.maps.LatLng(37.6264443920501, 127.078896187208)})
# positions.push({ title: '씨유세종대대양AI센터점', price: '3000', count: '1', latlng: new kakao.maps.LatLng(37.5507592599268, 127.074555630702)})
# positions.push({ title: '리코스타코인노래연습장', price: '3000', count: '1', latlng: new kakao.maps.LatLng(37.5421539451273, 127.068550278641)})
# positions.push({ title: '쿠팡', price: '8500', count: '1', latlng: new kakao.maps.LatLng(37.5157751181814, 127.099062233457)})
# positions.push({ title: '와이비엠넷', price: '113500', count: '1', latlng: new kakao.maps.LatLng(37.4020687071228, 127.106670696623)})
# positions.push({ title: '씨제이올리브영(주)공릉역점', price: '11000', count: '1', latlng: new kakao.maps.LatLng(37.62329725362, 127.06093893598)})
# positions.push({ title: '네이버파이낸셜(주)', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.3595166368758, 127.105210637192)})
# positions.push({ title: '빽다방서울과기대점', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.6286765044367, 127.077111260585)})
# positions.push({ title: '씨유공릉스타점', price: '7520', count: '1', latlng: new kakao.maps.LatLng(37.6267621309689, 127.075231190965)})
# positions.push({ title: '(주)롯데쇼핑', price: '30400', count: '1', latlng: new kakao.maps.LatLng(37.5648098108631, 126.981089534575)})
# positions.push({ title: '광림교회사회봉사관', price: '6500', count: '1', latlng: new kakao.maps.LatLng(37.5244103116445, 127.025383653787)})
# positions.push({ title: '장충동한방왕족발', price: '27000', count: '1', latlng: new kakao.maps.LatLng(37.5667820346901, 127.019804716203)})
# positions.push({ title: '일상다반', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.6262044778888, 127.076819841433)})
# positions.push({ title: '기린', price: '5900', count: '1', latlng: new kakao.maps.LatLng(36.7318599371288, 127.451090031658)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '악쓰는하마코인노래연습장2호점', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.6188160731152, 126.919604033116)})
# positions.push({ title: '굿모닝24시', price: '9000', count: '1', latlng: new kakao.maps.LatLng(37.5576808976743, 126.955201479765)})
# positions.push({ title: '쿠팡', price: '31890', count: '2', latlng: new kakao.maps.LatLng(37.5157751181814, 127.099062233457)})
# positions.push({ title: '씨유이수나누리점', price: '3000', count: '1', latlng: new kakao.maps.LatLng(37.4876448251511, 126.981013458035)})
# positions.push({ title: '방배세명약국', price: '23000', count: '1', latlng: new kakao.maps.LatLng(37.486747765286, 126.982666423995)})
# positions.push({ title: '네이버페이', price: '224692', count: '6', latlng: new kakao.maps.LatLng(37.5011928132831, 126.771628885256)})
# positions.push({ title: '이수통닭', price: '40000', count: '1', latlng: new kakao.maps.LatLng(37.4845531962979, 126.983412151216)})
# positions.push({ title: '삐삐핵볶이', price: '27000', count: '1', latlng: new kakao.maps.LatLng(37.6293964159781, 127.076521447735)})
# positions.push({ title: '아소코', price: '24000', count: '1', latlng: new kakao.maps.LatLng(35.1574449641625, 129.064714780916)})
# positions.push({ title: '왕창할인마트', price: '14500', count: '3', latlng: new kakao.maps.LatLng(37.4883946353717, 126.978344313895)})
# positions.push({ title: 'e-스타디움', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.5756407185216, 126.890045057198)})
# positions.push({ title: '동광약국', price: '72000', count: '1', latlng: new kakao.maps.LatLng(37.488312526452, 126.981935051977)})
# positions.push({ title: 'GS25사당신동아점', price: '1800', count: '1', latlng: new kakao.maps.LatLng(37.4884554912542, 126.979568529184)})
# positions.push({ title: '장미맨숀이수점', price: '43200', count: '1', latlng: new kakao.maps.LatLng(37.4840923090738, 126.98088534916)})
# positions.push({ title: '미니스톱이수태평점', price: '9000', count: '1', latlng: new kakao.maps.LatLng(37.4853207516005, 126.980932411468)})
# positions.push({ title: '(주)위메프', price: '29250', count: '1', latlng: new kakao.maps.LatLng(37.5096556162212, 127.063383582975)})
# positions.push({ title: '11번가', price: '4900', count: '1', latlng: new kakao.maps.LatLng(37.5555219467145, 126.97386054981)})
# positions.push({ title: '노랑통닭', price: '31000', count: '1', latlng: new kakao.maps.LatLng(37.5569932461807, 127.191100580674)})
# positions.push({ title: '주식회사아성다이소', price: '10000', count: '1', latlng: new kakao.maps.LatLng(35.2212533386035, 128.681235260685)})
# positions.push({ title: '동학', price: '33000', count: '1', latlng: new kakao.maps.LatLng(37.6290189853424, 127.076533068958)})
# positions.push({ title: 'GS25서울산업대', price: '9750', count: '1', latlng: new kakao.maps.LatLng(37.6278942792433, 127.077643902521)})
# positions.push({ title: '주)우아한형제들', price: '17500', count: '1', latlng: new kakao.maps.LatLng(37.5169302452841, 127.112781230361)})
# positions.push({ title: '세븐일레븐노원공릉그린점', price: '11000', count: '1', latlng: new kakao.maps.LatLng(37.6245976355883, 127.0783613752)})
# positions.push({ title: '(주)롯데쇼핑', price: '80100', count: '1', latlng: new kakao.maps.LatLng(37.5648098108631, 126.981089534575)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '씨유이수나누리점', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.4876448251511, 126.981013458035)})
# positions.push({ title: '왕창할인마트', price: '39350', count: '10', latlng: new kakao.maps.LatLng(37.4883946353717, 126.978344313895)})
# positions.push({ title: '주식회사아성다이소', price: '2000', count: '2', latlng: new kakao.maps.LatLng(35.2212533386035, 128.681235260685)})
# positions.push({ title: '방배세명약국', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.486747765286, 126.982666423995)})
# positions.push({ title: 'GS25사당신동아점', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.4884554912542, 126.979568529184)})
# positions.push({ title: '밥은', price: '9000', count: '1', latlng: new kakao.maps.LatLng(37.7870312180427, 128.907981003376)})
# positions.push({ title: '씨제이올리브영(주)방배이수점', price: '9000', count: '1', latlng: new kakao.maps.LatLng(37.4870137411983, 126.982654942468)})
# positions.push({ title: 'KCP-결제', price: '132510', count: '1', latlng: new kakao.maps.LatLng(37.4807029582644, 126.896158438099)})
# positions.push({ title: '락휴코인노래연습장건대중문점', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.5424054990141, 127.071297878859)})
# positions.push({ title: '빽다방서울과기대점', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.6286765044367, 127.077111260585)})
# positions.push({ title: '결', price: '10900', count: '1', latlng: new kakao.maps.LatLng(37.5716468397392, 126.983516239836)})
# positions.push({ title: '(주)에이플러스비', price: '55965', count: '1', latlng: new kakao.maps.LatLng(37.5043458078704, 127.045859932687)})
# positions.push({ title: '(주)위메프', price: '41720', count: '1', latlng: new kakao.maps.LatLng(37.5096556162212, 127.063383582975)})
# positions.push({ title: 'e-스타디움', price: '13100', count: '2', latlng: new kakao.maps.LatLng(37.5756407185216, 126.890045057198)})
# positions.push({ title: '열린약국', price: '8000', count: '1', latlng: new kakao.maps.LatLng(37.4857451724818, 127.08351086983)})
# positions.push({ title: '광주약국', price: '17000', count: '1', latlng: new kakao.maps.LatLng(33.4811445778114, 126.490041058368)})
# positions.push({ title: '이수태평파리바게뜨', price: '4600', count: '1', latlng: new kakao.maps.LatLng(37.4873127927481, 126.980945473631)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '메가커피이수태평점', price: '3900', count: '1', latlng: new kakao.maps.LatLng(37.4876352550898, 126.980893266007)})
# positions.push({ title: '씨유서울과학기술대1관점', price: '26860', count: '5', latlng: new kakao.maps.LatLng(37.6345240613145, 127.07728112475)})
# positions.push({ title: '유림복사', price: '2750', count: '1', latlng: new kakao.maps.LatLng(37.5834557806779, 126.998465360571)})
# positions.push({ title: '맘스터치', price: '15200', count: '3', latlng: new kakao.maps.LatLng(37.5178815192915, 126.906167641009)})
# positions.push({ title: '네이버페이', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.5011928132831, 126.771628885256)})
# positions.push({ title: '왕창할인마트', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.4883946353717, 126.978344313895)})
# positions.push({ title: '씨유이수나누리점', price: '2400', count: '1', latlng: new kakao.maps.LatLng(37.4876448251511, 126.981013458035)})
# positions.push({ title: '알파카피센터', price: '4550', count: '3', latlng: new kakao.maps.LatLng(37.4967852776426, 127.02764221559)})
# positions.push({ title: '킨코스코리아(주)', price: '5400', count: '1', latlng: new kakao.maps.LatLng(37.5550505044726, 126.920699628133)})
# positions.push({ title: '에그드랍강남본점', price: '8500', count: '1', latlng: new kakao.maps.LatLng(37.495662273058, 127.025597938141)})
# positions.push({ title: '쿠팡', price: '90900', count: '2', latlng: new kakao.maps.LatLng(37.5157751181814, 127.099062233457)})
# positions.push({ title: '길동우동공릉점', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.6262170742682, 127.073306458241)})
# positions.push({ title: '탐앤탐스공릉역점', price: '4100', count: '1', latlng: new kakao.maps.LatLng(37.6265124000315, 127.074628171091)})
# positions.push({ title: '네코정', price: '28500', count: '1', latlng: new kakao.maps.LatLng(37.6279956104976, 127.07686359966)})
# positions.push({ title: 'GS25하계협동문점', price: '1400', count: '1', latlng: new kakao.maps.LatLng(37.6363613570846, 127.07517889533)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '바나프레소삼성타운점', price: '6000', count: '2', latlng: new kakao.maps.LatLng(37.4954076853265, 127.027826145715)})
# positions.push({ title: '알파카피센터', price: '11800', count: '2', latlng: new kakao.maps.LatLng(37.4967852776426, 127.02764221559)})
# positions.push({ title: '알파강남본점', price: '1800', count: '1', latlng: new kakao.maps.LatLng(37.4967852776426, 127.02764221559)})
# positions.push({ title: '씨유강남승리점', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.4951230251758, 127.027962078063)})
# positions.push({ title: '방배세명약국', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.486747765286, 126.982666423995)})
# positions.push({ title: 'GS25사당우성', price: '3600', count: '2', latlng: new kakao.maps.LatLng(37.4874091674613, 126.980196016972)})
# positions.push({ title: '(주)코리아세븐과기대점', price: '15000', count: '2', latlng: new kakao.maps.LatLng(37.6277728658225, 127.09048756502)})
# positions.push({ title: '할리스커피종로3가점', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.5699488772432, 126.986807088116)})
# positions.push({ title: '씨유이수나누리점', price: '5200', count: '2', latlng: new kakao.maps.LatLng(37.4876448251511, 126.981013458035)})
# positions.push({ title: '장미맨숀이수점', price: '172700', count: '2', latlng: new kakao.maps.LatLng(37.4840923090738, 126.98088534916)})
# positions.push({ title: '위드미사당남사점', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.4835496286049, 126.980866831717)})
# positions.push({ title: '이디야이수중앙점', price: '2500', count: '1', latlng: new kakao.maps.LatLng(37.4846689361421, 126.979177332667)})
# positions.push({ title: '배스킨라빈스공릉점', price: '8200', count: '1', latlng: new kakao.maps.LatLng(37.6274647024526, 127.078576223252)})
# positions.push({ title: '이디야서울과기대점', price: '2500', count: '1', latlng: new kakao.maps.LatLng(37.6282962949983, 127.077787284753)})
# positions.push({ title: 'GS25서울산업대', price: '1500', count: '1', latlng: new kakao.maps.LatLng(37.6278942792433, 127.077643902521)})
# positions.push({ title: '무봉리토종순대국', price: '14000', count: '1', latlng: new kakao.maps.LatLng(37.8151886421439, 127.135395671079)})
# positions.push({ title: '키친로지', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.6262262942069, 127.078579677367)})
# positions.push({ title: '커피베이서울과학기술대학교점', price: '7200', count: '1', latlng: new kakao.maps.LatLng(37.6297193105373, 127.076132755144)})
# positions.push({ title: '블루마일스커피로스터즈', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.6265850954439, 127.076618479503)})
# positions.push({ title: '와플스타', price: '3500', count: '1', latlng: new kakao.maps.LatLng(37.6247099534864, 127.077870092024)})
# positions.push({ title: '다이소(공릉점)', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.6264557243819, 127.074491271089)})
# positions.push({ title: '주)스타벅스커피코리아', price: '4800', count: '1', latlng: new kakao.maps.LatLng(37.5601755439283, 126.982921061075)})
# positions.push({ title: 'CU홍대동교로점', price: '7500', count: '2', latlng: new kakao.maps.LatLng(37.5570888533458, 126.92249764259)})
# positions.push({ title: '김창훈포차', price: '72500', count: '1', latlng: new kakao.maps.LatLng(37.5445868965055, 127.069197500749)})
# positions.push({ title: '(주)탐앤탐스건대탐스커버리', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.5400394432377, 127.069383050648)})
# positions.push({ title: 'GS25사당이수역점', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.4881599256502, 126.981545782626)})
# positions.push({ title: '내가찜한닭강남역점', price: '24000', count: '1', latlng: new kakao.maps.LatLng(37.4998804830571, 127.02773484589)})
# positions.push({ title: '와이비엠넷', price: '2000', count: '1', latlng: new kakao.maps.LatLng(37.4020687071228, 127.106670696623)})
# positions.push({ title: '마쯔리', price: '86000', count: '1', latlng: new kakao.maps.LatLng(37.4318279054945, 127.130227183783)})
# positions.push({ title: '이디야커피서울숲점', price: '2500', count: '1', latlng: new kakao.maps.LatLng(37.6186447170128, 127.045610626326)})
# positions.push({ title: 'GS25사당신동아점', price: '1500', count: '1', latlng: new kakao.maps.LatLng(37.4884554912542, 126.979568529184)})
# positions.push({ title: '주식회사아성다이소', price: '1000', count: '1', latlng: new kakao.maps.LatLng(35.2212533386035, 128.681235260685)})
# positions.push({ title: '오센', price: '39500', count: '1', latlng: new kakao.maps.LatLng(37.4871925597254, 126.980707943447)})
# positions.push({ title: '스노우폭스플라워강남2호점', price: '7300', count: '1', latlng: new kakao.maps.LatLng(37.5006713666299, 127.027041892851)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '써브웨이', price: '12800', count: '1', latlng: new kakao.maps.LatLng(35.8842235941545, 128.656850477801)})
# positions.push({ title: '공차서울과학기술대점', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.6293964159781, 127.076521447735)})
# positions.push({ title: '투썸플레이스대학로점', price: '3800', count: '1', latlng: new kakao.maps.LatLng(37.5791742549942, 127.001795612107)})
# positions.push({ title: '주)스타벅스커피코리아', price: '8900', count: '2', latlng: new kakao.maps.LatLng(37.5601755439283, 126.982921061075)})
# positions.push({ title: 'GS25사당우성', price: '12500', count: '2', latlng: new kakao.maps.LatLng(37.4874091674613, 126.980196016972)})
# positions.push({ title: '지에스25강남시티힐점', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.5009839829803, 127.027956573334)})
# positions.push({ title: 'GS25성신행운', price: '5000', count: '1', latlng: new kakao.maps.LatLng(37.5892273301102, 127.020342137682)})
# positions.push({ title: '왕창할인마트', price: '11100', count: '3', latlng: new kakao.maps.LatLng(37.4883946353717, 126.978344313895)})
# positions.push({ title: 'GS25사당이수역점', price: '950', count: '1', latlng: new kakao.maps.LatLng(37.4881599256502, 126.981545782626)})
# positions.push({ title: '주)우아한형제들', price: '8000', count: '1', latlng: new kakao.maps.LatLng(37.5169302452841, 127.112781230361)})
# positions.push({ title: '장인닭갈비', price: '25500', count: '1', latlng: new kakao.maps.LatLng(35.2208448902244, 126.843716749104)})
# positions.push({ title: '보승회관', price: '42000', count: '1', latlng: new kakao.maps.LatLng(37.5539187763772, 127.077376623381)})
# positions.push({ title: '보화스위스', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.8690386382696, 127.718203403814)})
# positions.push({ title: '역전할머니맥주이수점', price: '17900', count: '1', latlng: new kakao.maps.LatLng(37.4863522910074, 126.980232251917)})
# positions.push({ title: '㈜이마트에브리데이사당동점', price: '4830', count: '1', latlng: new kakao.maps.LatLng(37.4897507862864, 126.978094820008)})
# positions.push({ title: '마쯔리', price: '124000', count: '1', latlng: new kakao.maps.LatLng(37.4318279054945, 127.130227183783)})
# positions.push({ title: '엔제리너스건대역', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.5403788036525, 127.070525733138)})
# positions.push({ title: '춘천집소문난집', price: '38000', count: '1', latlng: new kakao.maps.LatLng(37.5407002844582, 127.069912757288)})
# positions.push({ title: '씨제이올리브영(주)방배이수점', price: '45160', count: '2', latlng: new kakao.maps.LatLng(37.4870137411983, 126.982654942468)})
# positions.push({ title: '겐로쿠우동', price: '24500', count: '1', latlng: new kakao.maps.LatLng(37.5410734252121, 127.070908839841)})
# positions.push({ title: '(주)탐앤탐스건대탐스커버리', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.5400394432377, 127.069383050648)})
# positions.push({ title: '미스피츠(Misfits)', price: '14500', count: '1', latlng: new kakao.maps.LatLng(37.4825932514659, 126.981137975449)})
# positions.push({ title: '인쌩맥주이수역점', price: '12500', count: '1', latlng: new kakao.maps.LatLng(37.4862606351866, 126.980635705923)})
# positions.push({ title: '엔제리너스GS이수역DI점', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.4886819443995, 126.981965944898)})
# positions.push({ title: '아빠두리만든떡복이', price: '19000', count: '1', latlng: new kakao.maps.LatLng(37.5902175685, 127.009136884247)})
# positions.push({ title: '블루마일스커피로스터즈', price: '4500', count: '1', latlng: new kakao.maps.LatLng(37.6265850954439, 127.076618479503)})
# positions.push({ title: '씨유서울과기대점', price: '13500', count: '1', latlng: new kakao.maps.LatLng(37.6295843536003, 127.076394873773)})
# positions.push({ title: '네이버페이', price: '9340', count: '1', latlng: new kakao.maps.LatLng(37.5011928132831, 126.771628885256)})
# positions.push({ title: '(주)무신사', price: '46800', count: '1', latlng: new kakao.maps.LatLng(37.5278608384849, 127.036245575863)})
# positions.push({ title: 'UNITY', price: '25366', count: '1', latlng: new kakao.maps.LatLng(37.5001178464064, 127.03220096278)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>
# <div id="map" style="width:100%;height:100%;"></div><script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>
# <script>
# var mapContainer = document.getElementById('map'),
#     mapOption = {
#         center: new kakao.maps.LatLng(37.566826, 126.9786567),
#         level: 7
#     };
#     var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
#
#     // 마커를 표시할 위치와 title 객체 배열입니다
#
#     var positions = []
#     positions.push({ title: '서호김밥', price: '14000', count: '1', latlng: new kakao.maps.LatLng(37.491674275611, 126.986679860698)})
# positions.push({ title: 'GS25성수포레점', price: '10000', count: '1', latlng: new kakao.maps.LatLng(37.5457825428325, 127.042478660804)})
# positions.push({ title: '왕창할인마트', price: '29000', count: '4', latlng: new kakao.maps.LatLng(37.4883946353717, 126.978344313895)})
# positions.push({ title: '주식회사아성다이소', price: '6000', count: '1', latlng: new kakao.maps.LatLng(35.2212533386035, 128.681235260685)})
# positions.push({ title: '씨제이올리브영(주)방배이수점', price: '3600', count: '1', latlng: new kakao.maps.LatLng(37.4870137411983, 126.982654942468)})
# positions.push({ title: '북창동순두부(서초점)', price: '8500', count: '1', latlng: new kakao.maps.LatLng(37.4857978212987, 127.02023638278)})
# positions.push({ title: '항아리식당', price: '8000', count: '1', latlng: new kakao.maps.LatLng(37.4859420177697, 127.021565654083)})
# positions.push({ title: '(주)무신사', price: '52707', count: '1', latlng: new kakao.maps.LatLng(37.5278608384849, 127.036245575863)})
# positions.push({ title: '송황칼국수', price: '14000', count: '2', latlng: new kakao.maps.LatLng(37.5457004573426, 126.97015848742)})
# positions.push({ title: 'GS25서초프랜드점', price: '3500', count: '1', latlng: new kakao.maps.LatLng(37.4870201826423, 127.021954472701)})
# positions.push({ title: '내이처럼', price: '7300', count: '1', latlng: new kakao.maps.LatLng(37.4863522910074, 126.980232251917)})
# positions.push({ title: '신도박스산업', price: '1100', count: '1', latlng: new kakao.maps.LatLng(37.7042538659116, 126.629225770876)})
# positions.push({ title: '우정사업본부(우체국)', price: '7000', count: '1', latlng: new kakao.maps.LatLng(35.0331679958372, 126.718201392)})
# positions.push({ title: '월매네주막', price: '79500', count: '1', latlng: new kakao.maps.LatLng(37.4999272069783, 127.027897485884)})
# positions.push({ title: '데블다이스', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.500143045961, 127.027306332534)})
# positions.push({ title: '곱스떡스강남본점', price: '51600', count: '2', latlng: new kakao.maps.LatLng(37.5022605888391, 127.027311627407)})
# positions.push({ title: 'GS25강남YBM점', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.4994849454133, 127.028098958753)})
# positions.push({ title: '매화', price: '6000', count: '1', latlng: new kakao.maps.LatLng(37.5627952157497, 126.926280015143)})
# positions.push({ title: '우리집', price: '7500', count: '1', latlng: new kakao.maps.LatLng(37.5031002685999, 127.038788742065)})
# positions.push({ title: '탐앤탐스공릉역점', price: '4000', count: '1', latlng: new kakao.maps.LatLng(37.6265124000315, 127.074628171091)})
# positions.push({ title: '완산골명가남부터미널점', price: '6500', count: '1', latlng: new kakao.maps.LatLng(37.4853249649459, 127.02179636054)})
#
#     // 마커 이미지의 이미지 주소입니다
#     var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png";
#
#     for (var i = 0; i < positions.length; i ++) {
#
#         // 마커 이미지의 이미지 크기 입니다
#         //var imageSize = new kakao.maps.Size(24, 35);
#
#         // 마커 이미지를 생성합니다
#         //var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize);
#
#         // 마커를 생성합니다
#         var marker = new kakao.maps.Marker({
#             map: map, // 마커를 표시할 지도
#             position: positions[i].latlng, // 마커를 표시할 위치
#         //    title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
#         //    image : markerImage // 마커 이미지
#         });
#
#         var infowindow = new kakao.maps.InfoWindow({
#             //position : positions[i].latlng,
#             content : '<div style="width:100%;height:100%;font-size:11px">상호명 : ' + positions[i].title + '<br>방문횟수 : ' + positions[i].count + '<br>사용금액 : ' + positions[i].price +  '</div>'
#         });
#
#
#         kakao.maps.event.addListener(marker, 'mouseover', makeOverListener(map, marker, infowindow));
#         kakao.maps.event.addListener(marker, 'mouseout', makeOutListener(infowindow));
#
#         //marker.setMap(map);
#
#
#         //infowindow.open(map, marker);
#
#
#
#     }
#
#     function makeOverListener(map, marker, infowindow) {
#         return function() {
#             infowindow.open(map, marker);
#         };
#     }
#
#     // 인포윈도우를 닫는 클로저를 만드는 함수입니다
#     function makeOutListener(infowindow) {
#         return function() {
#             infowindow.close();
#         };
#     }
#
#     </script>

# %%
type(df_address_only)
# Out:
# list

# %%
data_in_name[1].loc[name]['사용금액']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-5bcbe8ed0f28> in <module>
# ----> 1 data_in_name[1].loc[name]['사용금액']
#
# IndexError: list index out of range
