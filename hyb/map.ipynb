# %%
import requests
 
 
def getLatLng(address):
    result = ""
 
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    rest_api_key = '289858dc68417f30677b064987b71bab'
    header = {'Authorization': 'KakaoAK ' + rest_api_key}
 
    r = requests.get(url, headers=header)
 
    if r.status_code == 200:
        result_address = r.json()["documents"][0]["address"]
        
        result = result_address["y"], result_address["x"]
    else:
        result = "ERROR[" + str(r.status_code) + "]"
    
    return result
 
 
def getKakaoMapHtml(address_latlng):
    javascript_key = "562beaefa8f3396ba21741328654bece"
 
    result = ""
    result = result + "<div id='map' style='width:1920px;height:1080px;display:inline-block;'></div>" + "\n"
    result = result + "<script type='text/javascript' src='//dapi.kakao.com/v2/maps/sdk.js?appkey=" + javascript_key + "'></script>" + "\n"
    result = result + "<script>" + "\n"
    result = result + "    var container = document.getElementById('map'); " + "\n"
    result = result + "    var options = {" + "\n"
    result = result + "           center: new kakao.maps.LatLng(" + address_latlng[0] + ", " + address_latlng[1] + ")," + "\n"
    result = result + "           level: 3" + "\n"
    result = result + "    }; " + "\n"
    result = result + "    var map = new kakao.maps.Map(container, options); " + "\n"
    
    # 검색한 좌표의 마커 생성을 위해 추가
    result = result + "    var markerPosition  = new kakao.maps.LatLng(" + address_latlng[0] + ", " + address_latlng[1] + ");  " + "\n"
    result = result + "    var marker = new kakao.maps.Marker({position: markerPosition}); " + "\n"
    result = result + "    marker.setMap(map); " + "\n"
 
    result = result + "</script>" + "\n"
    
    return result
 
# main()


map_html = ''

if __name__ == "__main__":
    address = "서울 강남구 선릉로 669"
    
    # 카카오 REST API로 좌표 구하기
    address_latlng = getLatLng(address)
    print(address_latlng)
 
    # 좌표로 지도 첨부 HTML 생성
    if str(address_latlng).find("ERROR") < 0:
        map_html = getKakaoMapHtml(address_latlng)
        
        print(map_html)
    else:
        print("[ERROR]getLatLng")
# Out:
# ('37.5166119773031', '127.041258693516')
# <div id='map' style='width:1920px;height:1080px;display:inline-block;'></div>
# <script type='text/javascript' src='//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece'></script>
# <script>
#     var container = document.getElementById('map');
#     var options = {
#            center: new kakao.maps.LatLng(37.5166119773031, 127.041258693516),
#            level: 3
#     };
#     var map = new kakao.maps.Map(container, options);
#     var markerPosition  = new kakao.maps.LatLng(37.5166119773031, 127.041258693516);
#     var marker = new kakao.maps.Marker({position: markerPosition});
#     marker.setMap(map);
# </script>

# %%
# address = input('주소를 입력하시오 ')
# store_name = input('가게 이름을 입력하시오 ')

address = [동작대로 29]
store_name = []

html = '''
<div id="map" style="width:1920px;height:1080px;"></div>

<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>
<script>
var mapContainer = document.getElementById('map'), // 지도를 표시할 div 
    mapOption = {
        center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표
        level: 3 // 지도의 확대 레벨
    };  

// 지도를 생성합니다    
var map = new kakao.maps.Map(mapContainer, mapOption); 

// 주소-좌표 변환 객체를 생성합니다
var geocoder = new kakao.maps.services.Geocoder();
'''
for i in range(len(address)):

    # 주소로 좌표를 검색합니다
    html = html + "geocoder.addressSearch('" + address[i] + "', function(result, status) {"

    html = html + '''
        // 정상적으로 검색이 완료됐으면 
         if (status === kakao.maps.services.Status.OK) {

            var coords = new kakao.maps.LatLng(result[0].y, result[0].x);

            // 결과값으로 받은 위치를 마커로 표시합니다
            var marker = new kakao.maps.Marker({
                map: map,
                position: coords
            });

            // 인포윈도우로 장소에 대한 설명을 표시합니다
            var infowindow = new kakao.maps.InfoWindow({
                content: '<div style="width:150px;text-align:center;padding:6px 0;">'''

    html = html + store_name[i] + '''</div>'
        });'''

html = html + '''
        infowindow.open(map, marker);

        // 지도의 중심을 결과값으로 받은 위치로 이동시킵니다
        map.setCenter(coords);
    } 
});    
</script>
'''
# Out:
# 주소를 입력하시오 동작대로 29길 91
# 가게 이름을 입력하시오 우리집

# %%
map_file = open('map.html', 'w')
map_file.write(html)
map_file.close()

# %%
print(html)
# Out:
# <div id="map" style="width:100%;height:350px;"></div>
#
# <script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>
# <script>
# var mapContainer = document.getElementById('map'), // 지도를 표시할 div
#     mapOption = {
#         center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표
#         level: 3 // 지도의 확대 레벨
#     };
#
# // 지도를 생성합니다
# var map = new kakao.maps.Map(mapContainer, mapOption);
# var address = new Array();
# address.push(동작대로 29길 91);
# for (var i = 0; i < 1; i ++) {
# geocoder.addressSearch('address.shift()', function(result, status) {
#
#     // 정상적으로 검색이 완료됐으면
#      if (status === kakao.maps.services.Status.OK) {
#
#         var coords = new kakao.maps.LatLng(result[0].y, result[0].x);
#
#         // 결과값으로 받은 위치를 마커로 표시합니다
#         var marker = new kakao.maps.Marker({
#             map: map,
#             position: coords
#         });
#
#         // 인포윈도우로 장소에 대한 설명을 표시합니다
# ...

# %%
# address = input('주소를 입력하시오 ')
# store_name = input('가게 이름을 입력하시오 ')

# address = ['동작대로 29길 91', '서울 서초구 효령로 335']
# store_name = ['우리집','플레이데이터']
# price = ['10000', '2000']

address = ['동작대로 29길 91']
store_name = ['우리집']
price = ['10000']

# address = []
# store_name = []
# price = []

html = '''
<div id="map" style="width:1920px;height:1080px;"></div>

<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>
<script>
var mapContainer = document.getElementById('map'), // 지도를 표시할 div 
    mapOption = {
        center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표
        level: 3 // 지도의 확대 레벨
    };  

// 지도를 생성합니다    
var map = new kakao.maps.Map(mapContainer, mapOption); 

// 주소-좌표 변환 객체를 생성합니다
var geocoder = new kakao.maps.services.Geocoder();
'''
for i in range(len(address)):

    # 주소로 좌표를 검색합니다
    html = html + "geocoder.addressSearch('" + address[i] + "', function(result, status) {"

    html = html + '''
        // 정상적으로 검색이 완료됐으면 
         if (status === kakao.maps.services.Status.OK) {
    '''
    
    html = html + f'\t var coords{i} = new kakao.maps.LatLng(result[0].y, result[0].x);'

    html = html + '''// 결과값으로 받은 위치를 마커로 표시합니다
                var marker = new kakao.maps.Marker({
                map: map,'''
    
    html = html + f'position: coords{i}'
    
    html = html + '''
            });

            // 인포윈도우로 장소에 대한 설명을 표시합니다
            var infowindow = new kakao.maps.InfoWindow({
                content: '<div style="width:150px;text-align:center;padding:6px 0;">'''

    html = html + f'{store_name[i]}\n 사용금액 : {price[i]}'

    html = html + '''</div>'
        });
        infowindow.open(map, marker);
    '''

    html = html + '''// 지도의 중심을 결과값으로 받은 위치로 이동시킵니다
            
        } 
    }\n'''
html = html + ''');    
</script>
'''

# %%
address = ['동작대로 29길 91']
store_name = ['우리집']
price = ['10000']

html = '<div id="map" style="width:100%;height:350px;"></div>\n'

html = html + '<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>\n'
html = html + '<script>\n'
html = html + "var mapContainer = document.getElementById('map'),\n" 
html = html + '\t mapOption = {\n'
html = html + '\t\t center: new kakao.maps.LatLng(33.450701, 126.570667), \n'
html = html + '\t\t level: 3 \n'
html = html + '\t};  \n'

# // 지도를 생성합니다    
html = html + 'var map = new kakao.maps.Map(mapContainer, mapOption); \n'

# // 주소-좌표 변환 객체를 생성합니다
html = html + 'var geocoder = new kakao.maps.services.Geocoder();\n'

for i in range(len(address)):
# // 주소로 좌표를 검색합니다
    html = html + f"geocoder.addressSearch('{address[i]}', function(result, status)" + '{\n'

    #     // 정상적으로 검색이 완료됐으면 
    html = html + '\t if (status === kakao.maps.services.Status.OK) {\n'

    html = html + f'\t\t var coords{i} = new kakao.maps.LatLng(result[0].y, result[0].x);\n'

    #         // 결과값으로 받은 위치를 마커로 표시합니다
    html = html + f'\t\t var marker{i} = new kakao.maps.Marker(' + '{\n'
    html = html + '\t\t\t map: map,\n'
    html = html + '\t\t\t position: coords\n'
    html = html + '\t\t });\n'

    #         // 인포윈도우로 장소에 대한 설명을 표시합니다
    html = html + '\t\t var infowindow = new kakao.maps.InfoWindow({\n'
    html = html + f"""\t\t\t content: '<div style="width:150px;text-align:center;padding:6px 0;">{store_name[i]} \n 사용금액 : {price[i]}</div>'"""
    html = html + '\t\t });\n'
    html = html + '\t\t infowindow.open(map, marker);\n'

    #         // 지도의 중심을 결과값으로 받은 위치로 이동시킵니다
    html = html + '\t\t map.setCenter(coords);\n'
    html = html + '\t } \n'
    html = html + '}'

html = html + ');    \n'
html = html + '</script>\n'

# %%
address = ['동작대로 29길 91']
store_name = ['우리집']
price = ['10000']

html = '''<div id="map" style="width:100%;height:350px;"></div>

<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>
<script>
var mapContainer = document.getElementById('map'), // 지도를 표시할 div 
    mapOption = {
        center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표
        level: 3 // 지도의 확대 레벨
    };  

// 지도를 생성합니다    
var map = new kakao.maps.Map(mapContainer, mapOption); 

// 주소-좌표 변환 객체를 생성합니다
var geocoder1 = new kakao.maps.services.Geocoder();

// 주소로 좌표를 검색합니다
geocoder1.addressSearch('제주특별자치도 제주시 첨단로 242', function(result, status) {

    // 정상적으로 검색이 완료됐으면 
     if (status === kakao.maps.services.Status.OK) {

        var coords = new kakao.maps.LatLng(result[0].y, result[0].x);

        // 결과값으로 받은 위치를 마커로 표시합니다
        var marker = new kakao.maps.Marker({
            map: map,
            position: coords
        });

        // 인포윈도우로 장소에 대한 설명을 표시합니다
        var infowindow = new kakao.maps.InfoWindow({
            content: '<div style="width:150px;text-align:center;padding:6px 0;">우리회사</div>'
        });
        infowindow.open(map, marker);

        // 지도의 중심을 결과값으로 받은 위치로 이동시킵니다
        map.setCenter(coords);
    } 
}

);    
</script>'''

# %%
address = ['동작대로 29길 91']
store_name = ['우리집']
price = ['10000']

html = '''<div id="map" style="width:100%;height:350px;"></div>

<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece&libraries=services"></script>
<script>
var mapContainer = document.getElementById('map'), // 지도를 표시할 div 
    mapOption = {
        center: new kakao.maps.LatLng(33.450701, 126.570667), // 지도의 중심좌표
        level: 3 // 지도의 확대 레벨
    };  

// 지도를 생성합니다    
var map = new kakao.maps.Map(mapContainer, mapOption); 
'''

html = html + 'var address = new Array();\n'

for i in range(len(address)):

    html = html + f'address.push({address[i]});\n'

'''
// 주소-좌표 변환 객체를 생성합니다
var geocoder = new kakao.maps.services.Geocoder();
'''


html = html + f'for (var i = 0; i < {len(address)}; i ++)'+' {\n'

html = html + "geocoder.addressSearch('address.shift()', function(result, status) {\n"
html = html + '''
    // 정상적으로 검색이 완료됐으면 
     if (status === kakao.maps.services.Status.OK) {

        var coords = new kakao.maps.LatLng(result[0].y, result[0].x);

        // 결과값으로 받은 위치를 마커로 표시합니다
        var marker = new kakao.maps.Marker({
            map: map,
            position: coords
        });

        // 인포윈도우로 장소에 대한 설명을 표시합니다
        var infowindow = new kakao.maps.InfoWindow({
            content: '<div style="width:150px;text-align:center;padding:6px 0;">우리회사</div>'
        });
        infowindow.open(map, marker);

        // 지도의 중심을 결과값으로 받은 위치로 이동시킵니다
        map.setCenter(coords);
    } 
});    
}

</script>'''

map_file = open('map.html', 'w')
map_file.write(html)
map_file.close()

print(html)

# %%
import requests

address = ['동작대로 29길 91']
coordinates_x = []
coordinates_y = []
store_name = ['우리집']
price = ['10000']
 
def getLatLng(address):
    result = ""
 
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    rest_api_key = '289858dc68417f30677b064987b71bab'
    header = {'Authorization': 'KakaoAK ' + rest_api_key}
 
    r = requests.get(url, headers=header)
 
    if r.status_code == 200:
        result_address = r.json()["documents"][0]["address"]
        
        result = result_address["y"], result_address["x"]
    else:
        result = "ERROR[" + str(r.status_code) + "]"
    
    return result
 
    
# 카카오 REST API로 좌표 구하기
for i in address:
    coordinates_x.append(getLatLng(i)[0])
    coordinates_y.append(getLatLng(i)[1])
    
n = len(address)
    
center_x = sum(float(coordinates_x)) / n
center_y = sum(float((coordinates_y)) / n
               
html = '<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>\n'
html = html + '<script>\n'
html = html + "var mapContainer = document.getElementById('map'), \n"
html = html + '    mapOption = { \n'

html = html + f'        center: new kakao.maps.LatLng({center_x}, {center_y}), \n'
html = html + '        level: 3 \n'
html = html + '    };'


html = html + """
var map = new kakao.maps.Map(mapContainer, mapOption); // 지도를 생성합니다
 
// 마커를 표시할 위치와 title 객체 배열입니다 

var positions = []
"""
for i in range(n):
    html = html + "positions.push = { title: " + f"'{store_name[i]}'," + f" latlng: new kakao.maps.LatLng({coordinates_x[i]}, {coordinates_y[i]})" + "}\n"

html = html + """
// 마커 이미지의 이미지 주소입니다
var imageSrc = "https://t1.daumcdn.net/localimg/localimages/07/mapapidoc/markerStar.png"; 
    
for (var i = 0; i < positions.length; i ++) {
    
    // 마커 이미지의 이미지 크기 입니다
    var imageSize = new kakao.maps.Size(24, 35); 
    
    // 마커 이미지를 생성합니다    
    var markerImage = new kakao.maps.MarkerImage(imageSrc, imageSize); 
    
    // 마커를 생성합니다
    var marker = new kakao.maps.Marker({
        map: map, // 마커를 표시할 지도
        position: positions[i].latlng, // 마커를 표시할 위치
        title : positions[i].title, // 마커의 타이틀, 마커에 마우스를 올리면 타이틀이 표시됩니다
        image : markerImage // 마커 이미지 
    });
}
</script>"""

map_file = open('map.html', 'w')
map_file.write(html)
map_file.close()

print(html)
# Out:
#   File "<ipython-input-25-a5736d6c0384>", line 38
#     html = '<script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=562beaefa8f3396ba21741328654bece"></script>\n'
#     ^
# SyntaxError: invalid syntax
